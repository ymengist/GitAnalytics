# %%
# get an integer from input, and output that integer squared, ending with newline

userNum = int(input())
userNumSquared = userNum * userNum   # Bug here; fix it when instructed
   
print(userNumSquared, end='\n')       # Output formatting issue here; fix it when instructed


# Remove the code that echoes the user's input back to the output, and submit again
print('Enter x: ')
x = int(input())

print('x doubled is:', (2 * x))


# Output a tree and a cat
# Draw tree
print('   *')
print('  ***')
print(' *****')
print('*******')
print('  ***')
print()
print()
print('/\   /\\') #Draw a cat
print('  o o')
print(' =   =')
print('  ---')

# Prompt the user for the number of cups of lemon juice, water, and sugar needed to make lemonade. Prompt the user to specify the number of servings the recipe yields. Output the ingredients and serving size. 
lemonJuiceCups = float(input('Enter amount of lemon juice (in cups):\n'))

waterCups = float(input('Enter amount of water (in cups):\n')) # FIXME (1): Finish reading other items into variables, then output the three ingrdients
   
agaveNectarCups = float(input('Enter amount of agave nectar (in cups):'))# FIXME (2): Prompt user for desired number of servings. Convert and output the ingredients

numberServings = float(input('\nHow many servings does this make?\n')) # FIXME (3): Convert and output the ingredients from (2) to gallons

print('\nLemonade ingredients - yields %s servings' %(numberServings))

print(lemonJuiceCups, 'cup(s) lemon juice')

print(waterCups, 'cup(s) water')

print(agaveNectarCups, 'cup(s) agave nectar')

howManyServings = float(input('\nHow many servings would you like to make?\n'))

xtender = howManyServings / numberServings

print('\nLemonade ingredients - yields %s servings' %(numberServings*xtender))

print(lemonJuiceCups*xtender, 'cup(s) lemon juice')

print(waterCups*xtender, 'cup(s) water')

print(agaveNectarCups*xtender, 'cup(s) agave nectar')

aCupPerGallon = 0.0625

print('\nLemonade ingredients - yields %s servings' %(numberServings*xtender))

print(lemonJuiceCups*xtender*aCupPerGallon, 'gallon(s) lemon juice')

print(waterCups*xtender*aCupPerGallon, 'gallon(s) water')

print(agaveNectarCups*xtender*aCupPerGallon, 'gallon(s) agave nectar')


# Prompt the user to input a food item name, price, and quantity. Output an itemized receipt.
itemName = input('Enter food item name:\n')

itemPrice = float(input('Enter item price:\n')) # FIXME (1): Finish reading item price and quantity, then output a receipt
   
itemQuantity = input('Enter item quantity:\n') # FIXME (2): Read in a second food item name, price, and quantity, then output a second receipt
   
# FIXME (3): Add a gratuity and total with tip to the second receipt

print('\nRECEIPT')
totalPrice = float(itemQuantity) * itemPrice
print(itemQuantity, itemName, '@ $ ' + str(itemPrice), '= $ ' + str(totalPrice) + '\nTotal cost: $', str(totalPrice) + '\n')

itemName2 = input('\nEnter second food item name:\n')

itemPrice2 = float(input('Enter item price:\n')) # FIXME (1): Finish reading item price and quantity, then output a receipt
   
itemQuantity2 = input('Enter item quantity:\n') # FIXME (2): Read in a second food item name, price, and quantity, then output a second receipt
   
# FIXME (3): Add a gratuity and total with tip to the second receipt

print('\nRECEIPT')
totalPrice2 = float(itemQuantity2) * itemPrice2

print(itemQuantity, itemName, '@ $', itemPrice, '= $', totalPrice)
print(itemQuantity2, itemName2, '@ $ '+ str(itemPrice2), '= $ ' + str(totalPrice2) + '\nTotal cost: $', totalPrice + totalPrice2)

print('\n15% gratuity: $', (totalPrice + totalPrice2)*0.15)
print('Total with tip: $', (totalPrice + totalPrice2)*1.15)


# Prompt the user to input a wall's height and width. Calculate and output the wall's area (integer)
import math

# Dictionary of paint colors and cost per gallon
paintColors = {
   'red': 35,
   'blue': 25,
   'green': 23
}
# Calculate and output wall area
wallHeight = float(input('Enter wall height (feet):\n'))
#FIXME (1): Prompt user to input wall's width
wallWidth = float(input('Enter wall width (feet):\n'))  
wallArea = wallWidth * wallHeight
print('Wall area: %1.0f square feet' % wallArea)

paintNeeded = wallArea / 350
cansNeeded = math.ceil(paintNeeded)

print('Paint needed: %f gallons' % paintNeeded)
print('Cans needed: %1.0f can(s)' % cansNeeded)

choiceColor = input('\nChoose a color to paint the wall:\n')

cost = int(paintColors[choiceColor]) * cansNeeded
        
print('Cost of purchasing %s paint:' % choiceColor, '$' + str(cost))


#Prompt the user for an automobile service. Output the user's input.
servicesAvailable = {'Oil change' : 35, 'Tire rotation' : 19, 'Car wash' : 7}

desiredAutoService = input('Enter desired auto service:\n')
print('You entered:', desiredAutoService)
for k, v in servicesAvailable.items():
    if k != desiredAutoService:
        continue
    else:
        costAutoService = v
        print('Cost of %s:' % desiredAutoService.lower(), '$' + str(costAutoService))
        break
else:
    print('Error: Requested service is not recognized')
    
    
#Output a menu of automotive services and the corresponding cost of each service.
DavysAutoShopServices = {'Oil change' : 35, 'Tire rotation' : 19, 'Car wash' : 7, 'Car wax' : 12, '-' : 'No service'}

print("Davy's auto shop services")
for k, v in DavysAutoShopServices.items():
    if k == '-':
        break
    else:
        print(k, '--', '$' + str(v), end='\n')

firstService = input('\nSelect first service:\n')
secondService = input('Select second service:\n')
print("\nDavy's auto shop invoice\n")
for k, v in DavysAutoShopServices.items():
    if k == firstService and firstService != '-':
        print('Service 1: %s,' % k, '$' + str(v))
        break
    else:
        continue
else:
    print('Service 1: %s' % DavysAutoShopServices['-'])

for k, v in DavysAutoShopServices.items():
    if k == secondService and secondService != '-':
        print('Service 2: %s,' % k, '$' + str(v))
        break
    else:
        continue
else:
    print('Service 2: %s' % DavysAutoShopServices['-'])

if DavysAutoShopServices[firstService] == 'No service':
    DavysAutoShopServices[firstService] = 0
if DavysAutoShopServices[secondService] == 'No service':
    DavysAutoShopServices[secondService] = 0
    
print('\nTotal:', '$' + str(DavysAutoShopServices[firstService] + DavysAutoShopServices[secondService]))


#This program outputs a downwards facing arrow composed of a rectangle and a right triangle. The arrow dimensions are defined by user specified arrow base height, arrow base width, and arrow head width.
arrow_base_height = int(input('Enter arrow base height:\n'))

arrow_base_width = int(input('Enter arrow base width:\n'))

arrow_head_width = int(input('Enter arrow head width:\n'))

while arrow_head_width <= arrow_base_width:
    arrow_head_width = int(input('Enter arrow head width:\n'))
    
print()
char = '*'
if arrow_head_width > arrow_base_width:
    counter = arrow_head_width
    for i in range(1, arrow_base_height + 1):  
        print(char * arrow_base_width)

counter = arrow_head_width
while counter > 0:
    print(char * counter)
    counter -= 1
